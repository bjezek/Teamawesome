# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

# reading data
df = pd.read_csv("../archive/TweetsElonMusk.csv")
df_lines = df.groupby('name').count()
df_lines = df_lines.sort_values(by=['tweet'], ascending=False)[:10]
names = df_lines.index.values

# filtering out non-top characters
df_sentiment = df[df['name'].isin(names)]
df_sentiment = df_sentiment[['name', 'tweet']]

# calculating sentiment score
sid = SentimentIntensityAnalyzer()
df_sentiment.reset_index(inplace=True, drop=True)
df_sentiment[['neg', 'neu', 'pos', 'compound']] = df_sentiment['tweet'].apply(sid.polarity_scores).apply(pd.Series)
df_sentiment
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/gautamseenivasan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#             name                                              tweet    neg  \
# 0      Elon Musk  @vincent13031925 For now. Costs are decreasing...  0.000
# 1      Elon Musk                           Love this beautiful shot  0.000
# 2      Elon Musk  @agnostoxxx @CathieDWood @ARKInvest Trust the ...  0.000
# 3      Elon Musk                 The art In Cyberpunk is incredible  0.000
# 4      Elon Musk                                    @itsALLrisky 🤣🤣  0.000
# ...          ...                                                ...    ...
# 12557  Elon Musk  @eugenelee3 @PPathole @SpaceX @Tesla Yeah, not...  0.000
# 12558  Elon Musk  @PPathole @SpaceX @Tesla That was my night job...  0.000
# 12559  Elon Musk  @PPathole @SpaceX @Tesla True. Ancient times …...  0.000
# ...

# %%
bitcoin_tweets = pd.DataFrame(df["tweet"].str.contains("BTC", "Bitcoin"))


bitcoin_tweets = bitcoin_tweets[bitcoin_tweets['tweet'] == True]
 

bitcoin_tweets['tweetmessage'] = df["tweet"]
print(bitcoin_tweets)
# Out:
#       tweet                                       tweetmessage
# 244    True  BTC (Bitcoin) is an anagram of TBC(The Boring ...
# 401    True  @PeterSchiff That said, BTC &amp; ETH do seem ...
# 472    True  @itsALLrisky Doge appears to be inflationary, ...
# 569    True      @DocumentingBTC The dollar is shorting itself
# 6746   True  @Tom_Heats @coindesk Whoever owns the early BT...
# 6747   True  @coindesk That said, I still only own 0.25 BTC...
# 9229   True  @DeadlyBananas @MichaelAVaughn Not sure. I let...
# 9455   True  @ThisIsSandeepG Not true. A friend sent me par...

# %%
dogecoin_tweets = pd.DataFrame(df["tweet"].str.contains("Dogecoin"))


dogecoin_tweets = dogecoin_tweets[dogecoin_tweets['tweet'] == True]
 

dogecoin_tweets['tweetmessage'] = df["tweet"]
print(dogecoin_tweets)
# Out:
#        tweet                                       tweetmessage
# 103     True  SpaceX is going to put a literal Dogecoin on t...
# 234     True  Origin of Doge Day Afternoon: The ancient Roma...
# 325     True                 @draecomino 2022: Dogecoin is dumb
# 430     True  If major Dogecoin holders sell most of their c...
# 452     True  Bought some Dogecoin for lil X, so he can be a...
# 486     True                      @Jbuttermost @Dogecoinrich 🤣🤣
# 488     True                                   @Dogecoinrich 🤣🤣
# 527     True                    Dogecoin is the people’s crypto
# 3153    True       @28delayslater @justpaulinelol Dogecoin Mode
# 6395    True   Dogecoin value may vary  https://t.co/UWerAhPv63
# 6396    True             Dogecoin rulz  https://t.co/flWWUgAgLU
# 6398    True  @Tom_Heats Dogecoin might be my fav cryptocurr...
# 12530   True                        @sadiaslayy @DogecoinBets 😮

# %%
Tesla_tweets = pd.DataFrame(df["tweet"].str.contains("Tesla", "TSLA"))


Tesla_tweets = Tesla_tweets[Tesla_tweets['tweet'] == True]
 

Tesla_tweets['tweetmessage'] = df["tweet"]
print(Tesla_tweets)
# Out:
#        tweet                                       tweetmessage
# 26      True  @AustinTeslaClub @OwenSparks_ @WholeMarsBlog G...
# 38      True                                    @TeslaGong Yeah
# 48      True  @IheartTesla Absolutely doable. Possibly as so...
# 52      True  @IheartTesla @neuralink Hopefully, later this ...
# 59      True  Thanks Tesla suppliers for providing us with c...
# ...      ...                                                ...
# 12557   True  @eugenelee3 @PPathole @SpaceX @Tesla Yeah, not...
# 12558   True  @PPathole @SpaceX @Tesla That was my night job...
# 12559   True  @PPathole @SpaceX @Tesla True. Ancient times …...
# 12560   True                  @Erdayastronaut @Tesla Absolutely
# 12561   True  @Erdayastronaut @Tesla Tesla is building up co...
#
# [2033 rows x 2 columns]

# %%
Twitter_tweets = pd.DataFrame(df["tweet"].str.contains("Twitter", "TWTR"))


Twitter_tweets = Twitter_tweets[Twitter_tweets['tweet'] == True]
 

Twitter_tweets['tweetmessage'] = df["tweet"]
print(Twitter_tweets)
# Out:
#        tweet                                       tweetmessage
# 139     True  @RationalEtienne @TwitterSupport @jack This ap...
# 188     True  @Erdayastronaut @Twitter @TwitterComms @verifi...
# 534     True                            Off Twitter for a while
# 1610    True  @ID_AA_Carmack For Dojo, we’re betting on FP16...
# 1968    True  @RationalEtienne @BernieSanders I wonder if he...
# ...      ...                                                ...
# 10358   True  Signing off now. That was more than enough Twi...
# 10384   True  @BullFlags Yeah. And Twitter is a hater Hellsc...
# 10902   True  @apple_defense @samabuelsamid Exactly! I love ...
# 11100   True  Signing off from impromptu Twitter AMA. Thanks...
# 11439   True  What are the best riddles you've heard that ar...
#
# [65 rows x 2 columns]

# %%
bitcoin_tweets_sentiment = pd.DataFrame()
sid = SentimentIntensityAnalyzer()
bitcoin_tweets.reset_index(inplace=True, drop=True)
bitcoin_tweets_sentiment[['neg', 'neu', 'pos', 'compound']] = bitcoin_tweets['tweetmessage'].apply(sid.polarity_scores).apply(pd.Series)
bitcoin_tweets_sentiment["tweet"] = bitcoin_tweets["tweetmessage"]
bitcoin_tweets_sentiment


bitcoin_tweets_sentiment["Date"] = df["date"]

bitcoin_tweets_sentiment.loc[]
# Out:
#      neg    neu    pos  compound  \
# 0  0.206  0.794  0.000   -0.3802
# 1  0.000  0.763  0.237    0.4215
# 2  0.142  0.772  0.087   -0.3291
# 3  0.000  1.000  0.000    0.0000
# 4  0.107  0.562  0.331    0.6124
# 5  0.000  0.856  0.144    0.4939
# 6  0.050  0.806  0.144    0.5885
# 7  0.188  0.812  0.000   -0.3570
#
#                                                tweet        Date
# 0  BTC (Bitcoin) is an anagram of TBC(The Boring ...  2021-04-11
# 1  @PeterSchiff That said, BTC &amp; ETH do seem ...  2021-04-11
# 2  @itsALLrisky Doge appears to be inflationary, ...  2021-04-11
# 3      @DocumentingBTC The dollar is shorting itself  2021-04-11
# 4  @Tom_Heats @coindesk Whoever owns the early BT...  2021-04-11
# 5  @coindesk That said, I still only own 0.25 BTC...  2021-04-11
# 6  @DeadlyBananas @MichaelAVaughn Not sure. I let...  2021-04-11
# 7  @ThisIsSandeepG Not true. A friend sent me par...  2021-04-11

# %%
# for pos value over .80
#best_sentiment = pd.DataFrame(df_sentiment['pos'] > .80)
#best_sentiment["tweet"] = df["tweet"]

# %%
#best_sentiment = best_sentiment[best_sentiment['pos'] == True]

# %%
#best_sentiment.head()
# Out:
#       pos                     tweet
# 1    True  Love this beautiful shot
# 250  True        @DraperYounce Wow!
# 376  True      @PPathole Super cool
# 407  True   @NASA Congratulations!!
# 505  True                 Much wow!

# %%
#sa = SentimentIntensityAnalyzer()
#sa.lexicon
# Out:
# {'$:': -1.5,
#  '%)': -0.4,
#  '%-)': -1.5,
#  '&-:': -0.4,
#  '&:': -0.7,
#  "( '}{' )": 1.6,
#  '(%': -0.9,
#  "('-:": 2.2,
#  "(':": 2.3,
#  '((-:': 2.1,
#  '(*': 1.1,
#  '(-%': -0.7,
#  '(-*': 1.3,
#  '(-:': 1.6,
#  '(-:0': 2.8,
#  '(-:<': -0.4,
#  '(-:o': 1.5,
#  '(-:O': 1.5,
#  '(-:{': -0.1,
#  '(-:|>*': 1.9,
#  '(-;': 1.3,
#  '(-;|': 2.1,
#  '(8': 2.6,
#  '(:': 2.2,
#  '(:0': 2.4,
#  '(:<': -0.2,
#  '(:o': 2.5,
#  '(:O': 2.5,
#  '(;': 1.1,
#  '(;<': 0.3,
#  '(=': 2.2,
#  '(?:': 2.1,
#  '(^:': 1.5,
#  '(^;': 1.5,
#  '(^;0': 2.0,
#  '(^;o': 1.9,
#  '(o:': 1.6,
#  ")':": -2.0,
#  ")-':": -2.1,
#  ')-:': -2.1,
#  ')-:<': -2.2,
#  ')-:{': -2.1,
#  '):': -1.8,
#  '):<': -1.9,
#  '):{': -2.3,
#  ');<': -2.6,
#  '*)': 0.6,
#  '*-)': 0.3,
#  '*-:': 2.1,
#  '*-;': 2.4,
#  '*:': 1.9,
#  '*<|:-)': 1.6,
#  '*\\0/*': 2.3,
#  '*^:': 1.6,
#  ',-:': 1.2,
#  "---'-;-{@": 2.3,
#  '--<--<@': 2.2,
#  '.-:': -1.2,
#  '..###-:': -1.7,
#  '..###:': -1.9,
#  '/-:': -1.3,
#  '/:': -1.3,
# ...

# %%
 new_words = {
    'Bitcoin': -2.0,
    'Dogecoin': -3.1,
}

sa.lexicon.update(new_words)

# %%
sentiment = [best_sentiment["tweet"]
    ]

for review in sentiment:
    scores = sa.polarity_scores(review)
    print(scores['compound'], review)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [62], in <cell line: 4>()
#       1 sentiment = [best_sentiment["tweet"]
#       2     ]
#       4 for review in sentiment:
# ----> 5     scores = sa.polarity_scores(review)
#       6     print(scores['compound'], review)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/nltk/sentiment/vader.py:361, in SentimentIntensityAnalyzer.polarity_scores(self, text)
#     355 """
#     356 Return a float for sentiment strength based on the input text.
#     357 Positive values are positive valence, negative value are negative
#     358 valence.
#     359 """
#     360 # text, words_and_emoticons, is_cap_diff = self.preprocess(text)
# --> 361 sentitext = SentiText(
#     362     text, self.constants.PUNC_LIST, self.constants.REGEX_REMOVE_PUNCTUATION
#     363 )
#     364 sentiments = []
# ...
